# %%
# USOPC - Triathlon

import pandas as pd # library for data analysis
import requests # library to handle requests
from bs4 import BeautifulSoup # library to parse HTML documents
import numpy as np
from wikitable import wikitable # library to handle wikitables

# %%
# Get wikipedia tables

url = "https://en.wikipedia.org/wiki/Triathlon_at_the_2024_Summer_Olympics_%E2%80%93_Qualification#Men's"
summarydf = wikitable(url, to_csv=True, overwrite=True, table_number=1)
print(summarydf)
# Out:
#              NOC  Men  Women  Mixed  Total
# 0         France    2      2    NaN      4
# 1  Great Britain    2      2    NaN      4
# 2  Total: 2 NOCs    4      4    8.0      8

# %%
# Replace NaN with 1 for Yes/Qualified

summarydf = summarydf.replace(np.nan, 1)
print(summarydf)
# Out:
#              NOC  Men  Women  Mixed  Total
# 0         France    2      2    1.0      4
# 1  Great Britain    2      2    1.0      4
# 2  Total: 2 NOCs    4      4    8.0      8

# %%
# Get wikipedia tables

url = "https://en.wikipedia.org/wiki/Triathlon_at_the_2024_Summer_Olympics_%E2%80%93_Qualification#Men's"
eventsdf = wikitable(url, to_csv=True, overwrite=True, table_number=2)
print(eventsdf)
# Out:
#                                                Event                     Date  \
# 0     2022 World Triathlon Mixed Relay Championships            June 26, 2022
# 1     2023 World Triathlon Mixed Relay Championships      July 15–16, 2023[4]
# 2  2024 World Triathlon Mixed Relay Olympic Quali...  April 15 – May 27, 2024
# 3         Mixed Relay Olympic Qualification Rankings           March 25, 2024
# 4          Individual Olympic Qualification Rankings             May 27, 2024
#
#       Venue
# 0  Montreal
# 1   Hamburg
# 2       TBA
# 3         —
# 4         —

# %%
# Get wikipedia tables

url = "https://en.wikipedia.org/wiki/Triathlon_at_the_2024_Summer_Olympics_%E2%80%93_Qualification#Men's"
mensdf = wikitable(url, to_csv=True, overwrite=True, table_number=3)
print(mensdf)
# Out:
#                                                 Event  Places  Qualified NOC  \
# 0                                         Host nation       2         France
# 1                                         Host nation       2         France
# 2      2022 World Triathlon Mixed Relay Championships       2  Great Britain
# 3      2022 World Triathlon Mixed Relay Championships       2  Great Britain
# 4      2023 World Triathlon Mixed Relay Championships       2            NaN
# 5      2023 World Triathlon Mixed Relay Championships       2            NaN
# 6                  Mixed Relay Qualification Rankings      12            NaN
# 7                  Mixed Relay Qualification Rankings      12            NaN
# 8                  Mixed Relay Qualification Rankings      12            NaN
# 9                  Mixed Relay Qualification Rankings      12            NaN
# 10                 Mixed Relay Qualification Rankings      12            NaN
# 11                 Mixed Relay Qualification Rankings      12            NaN
# 12                 Mixed Relay Qualification Rankings      12            NaN
# 13                 Mixed Relay Qualification Rankings      12            NaN
# 14                 Mixed Relay Qualification Rankings      12            NaN
# 15                 Mixed Relay Qualification Rankings      12            NaN
# 16                 Mixed Relay Qualification Rankings      12            NaN
# 17                 Mixed Relay Qualification Rankings      12            NaN
# 18  2024 World Triathlon Mixed Relay Qualification...       4            NaN
# 19  2024 World Triathlon Mixed Relay Qualification...       4            NaN
# 20  2024 World Triathlon Mixed Relay Qualification...       4            NaN
# 21  2024 World Triathlon Mixed Relay Qualification...       4            NaN
# 22                        Individual Olympic Rankings      26            NaN
# 23                        Individual Olympic Rankings      26            NaN
# 24                        Individual Olympic Rankings      26            NaN
# 25                        Individual Olympic Rankings      26            NaN
# 26                        Individual Olympic Rankings      26            NaN
# 27                        Individual Olympic Rankings      26            NaN
# 28                        Individual Olympic Rankings      26            NaN
# 29                        Individual Olympic Rankings      26            NaN
# 30                        Individual Olympic Rankings      26            NaN
# 31                        Individual Olympic Rankings      26            NaN
# 32                        Individual Olympic Rankings      26            NaN
# 33                        Individual Olympic Rankings      26            NaN
# 34                        Individual Olympic Rankings      26            NaN
# 35                        Individual Olympic Rankings      26            NaN
# 36                        Individual Olympic Rankings      26            NaN
# 37                        Individual Olympic Rankings      26            NaN
# 38                        Individual Olympic Rankings      26            NaN
# 39                        Individual Olympic Rankings      26            NaN
# 40                        Individual Olympic Rankings      26            NaN
# 41                        Individual Olympic Rankings      26            NaN
# 42                        Individual Olympic Rankings      26            NaN
# 43                        Individual Olympic Rankings      26            NaN
# 44                        Individual Olympic Rankings      26            NaN
# 45                        Individual Olympic Rankings      26            NaN
# 46                        Individual Olympic Rankings      26            NaN
# 47                        Individual Olympic Rankings      26            NaN
# 48               Individual Olympic Rankings – Africa       1            NaN
# 49             Individual Olympic Rankings – Americas       1            NaN
# 50                 Individual Olympic Rankings – Asia       1            NaN
# 51               Individual Olympic Rankings – Europe       1            NaN
# 52              Individual Olympic Rankings – Oceania       1            NaN
# 53                              Tripartite Commission       2            NaN
# 54                              Tripartite Commission       2            NaN
# 55                                              Total      55            NaN
#
#     Selected triathlete
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# 5                   NaN
# 6                   NaN
# 7                   NaN
# 8                   NaN
# 9                   NaN
# 10                  NaN
# 11                  NaN
# 12                  NaN
# 13                  NaN
# 14                  NaN
# 15                  NaN
# 16                  NaN
# 17                  NaN
# 18                  NaN
# 19                  NaN
# 20                  NaN
# 21                  NaN
# 22                  NaN
# 23                  NaN
# 24                  NaN
# 25                  NaN
# 26                  NaN
# 27                  NaN
# 28                  NaN
# 29                  NaN
# 30                  NaN
# 31                  NaN
# 32                  NaN
# 33                  NaN
# 34                  NaN
# 35                  NaN
# 36                  NaN
# 37                  NaN
# 38                  NaN
# 39                  NaN
# 40                  NaN
# 41                  NaN
# 42                  NaN
# 43                  NaN
# 44                  NaN
# 45                  NaN
# 46                  NaN
# 47                  NaN
# 48                  NaN
# 49                  NaN
# 50                  NaN
# 51                  NaN
# 52                  NaN
# 53                  NaN
# 54                  NaN
# 55                  NaN

# %%
# Get wikipedia tables

url = "https://en.wikipedia.org/wiki/Triathlon_at_the_2024_Summer_Olympics_%E2%80%93_Qualification#Men's"
womensdf = wikitable(url, to_csv=True, overwrite=True, table_number=4)
print(womensdf)
# Out:
#                                                 Event  Places  Qualified NOC  \
# 0                                         Host nation       2         France
# 1                                         Host nation       2         France
# 2      2022 World Triathlon Mixed Relay Championships       2  Great Britain
# 3      2022 World Triathlon Mixed Relay Championships       2  Great Britain
# 4      2023 World Triathlon Mixed Relay Championships       2            NaN
# 5      2023 World Triathlon Mixed Relay Championships       2            NaN
# 6                  Mixed Relay Qualification Rankings      12            NaN
# 7                  Mixed Relay Qualification Rankings      12            NaN
# 8                  Mixed Relay Qualification Rankings      12            NaN
# 9                  Mixed Relay Qualification Rankings      12            NaN
# 10                 Mixed Relay Qualification Rankings      12            NaN
# 11                 Mixed Relay Qualification Rankings      12            NaN
# 12                 Mixed Relay Qualification Rankings      12            NaN
# 13                 Mixed Relay Qualification Rankings      12            NaN
# 14                 Mixed Relay Qualification Rankings      12            NaN
# 15                 Mixed Relay Qualification Rankings      12            NaN
# 16                 Mixed Relay Qualification Rankings      12            NaN
# 17                 Mixed Relay Qualification Rankings      12            NaN
# 18  2024 World Triathlon Mixed Relay Qualification...       4            NaN
# 19  2024 World Triathlon Mixed Relay Qualification...       4            NaN
# 20  2024 World Triathlon Mixed Relay Qualification...       4            NaN
# 21  2024 World Triathlon Mixed Relay Qualification...       4            NaN
# 22                        Individual Olympic Rankings      26            NaN
# 23                        Individual Olympic Rankings      26            NaN
# 24                        Individual Olympic Rankings      26            NaN
# 25                        Individual Olympic Rankings      26            NaN
# 26                        Individual Olympic Rankings      26            NaN
# 27                        Individual Olympic Rankings      26            NaN
# 28                        Individual Olympic Rankings      26            NaN
# 29                        Individual Olympic Rankings      26            NaN
# 30                        Individual Olympic Rankings      26            NaN
# 31                        Individual Olympic Rankings      26            NaN
# 32                        Individual Olympic Rankings      26            NaN
# 33                        Individual Olympic Rankings      26            NaN
# 34                        Individual Olympic Rankings      26            NaN
# 35                        Individual Olympic Rankings      26            NaN
# 36                        Individual Olympic Rankings      26            NaN
# 37                        Individual Olympic Rankings      26            NaN
# 38                        Individual Olympic Rankings      26            NaN
# 39                        Individual Olympic Rankings      26            NaN
# 40                        Individual Olympic Rankings      26            NaN
# 41                        Individual Olympic Rankings      26            NaN
# 42                        Individual Olympic Rankings      26            NaN
# 43                        Individual Olympic Rankings      26            NaN
# 44                        Individual Olympic Rankings      26            NaN
# 45                        Individual Olympic Rankings      26            NaN
# 46                        Individual Olympic Rankings      26            NaN
# 47                        Individual Olympic Rankings      26            NaN
# 48               Individual Olympic Rankings – Africa       1            NaN
# 49             Individual Olympic Rankings – Americas       1            NaN
# 50                 Individual Olympic Rankings – Asia       1            NaN
# 51               Individual Olympic Rankings – Europe       1            NaN
# 52              Individual Olympic Rankings – Oceania       1            NaN
# 53                              Tripartite Commission       2            NaN
# 54                              Tripartite Commission       2            NaN
# 55                                              Total      55            NaN
#
#     Selected triathlete
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# 5                   NaN
# 6                   NaN
# 7                   NaN
# 8                   NaN
# 9                   NaN
# 10                  NaN
# 11                  NaN
# 12                  NaN
# 13                  NaN
# 14                  NaN
# 15                  NaN
# 16                  NaN
# 17                  NaN
# 18                  NaN
# 19                  NaN
# 20                  NaN
# 21                  NaN
# 22                  NaN
# 23                  NaN
# 24                  NaN
# 25                  NaN
# 26                  NaN
# 27                  NaN
# 28                  NaN
# 29                  NaN
# 30                  NaN
# 31                  NaN
# 32                  NaN
# 33                  NaN
# 34                  NaN
# 35                  NaN
# 36                  NaN
# 37                  NaN
# 38                  NaN
# 39                  NaN
# 40                  NaN
# 41                  NaN
# 42                  NaN
# 43                  NaN
# 44                  NaN
# 45                  NaN
# 46                  NaN
# 47                  NaN
# 48                  NaN
# 49                  NaN
# 50                  NaN
# 51                  NaN
# 52                  NaN
# 53                  NaN
# 54                  NaN
# 55                  NaN

# %%
# Export tables as csv

summarydf.to_csv(r'C:\Users\andyr\OneDrive\Desktop\USOPC\summarydf.csv')
eventsdf.to_csv(r'C:\Users\andyr\OneDrive\Desktop\USOPC\eventsdf.csv')
mensdf.to_csv(r'C:\Users\andyr\OneDrive\Desktop\USOPC\mensdf.csv')
womensdf.to_csv(r'C:\Users\andyr\OneDrive\Desktop\USOPC\womensdf.csv')

# %%
# Import files from triathlon.com for verification Tableau

elite_men = pd.read_csv(r'C:\Users\andyr\OneDrive\Desktop\USOPC\OlympicEliteMen.csv')
elite_women = pd.read_csv(r'C:\Users\andyr\OneDrive\Desktop\USOPC\OlympicEliteWomen.csv')
mixedrelay = pd.read_csv(r'C:\Users\andyr\OneDrive\Desktop\USOPC\OlympicMixedRelay.csv')

elite_men.head()
# Out:
#    Rank  Prior Rank Rank Change First Name Last Name   YOB Country  \
# 0     1           1           0        L�o   Bergere  1996     FRA
# 1     2           2           0       Alex       Yee  1998     GBR
# 2     3           3           0      Jelle     Geens  1993     BEL
# 3     4           4           0    Vincent      Luis  1989     FRA
# 4     5           6           1     Hayden     Wilde  1997     NZL
#
#    Total Points  Events First Period  Events Second Period  ...  \
# 0     4613.2000                    6                     0  ...
# 1     4346.4100                    5                     0  ...
# 2     3936.8545                    6                     0  ...
# 3     3684.8900                    6                     0  ...
# 4     3553.3200                    6                     0  ...
#
#    Period 1 5th Score  Period 1 6th Score  Period 1 7th Score  \
# 0              650.00            593.5900                 NaN
# 1              732.09                 NaN                 NaN
# 2              434.56            399.7245                 NaN
# 3              371.82            343.9400                 NaN
# 4              375.00             22.4600                 NaN
#
#    Period 2 Best Score  Period 2 2nd Score  Period 2 3rd Score  \
# 0                  NaN                 NaN                 NaN
# 1                  NaN                 NaN                 NaN
# 2                  NaN                 NaN                 NaN
# 3                  NaN                 NaN                 NaN
# 4                  NaN                 NaN                 NaN
#
#    Period 2 4th Score  Period 2 5th Score  Period 2 6th Score  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#    Period 2 7th Score
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#
# [5 rows x 26 columns]

# %%
#only keep columns 'col1' and 'col2'
elite_men = elite_men[['Rank', 'First Name', 'Last Name', 'Country', 'Total Points']]

# %%
elite_women.head()
# Out:
#    Rank  Prior Rank Rank Change First Name     Last Name   YOB Country  \
# 0     1           1           0     Taylor        Spivey  1991     USA
# 1     2           2           0       Beth        Potter  1991     GBR
# 2     3           3           0    Georgia  Taylor-Brown  1994     GBR
# 3     4           4           0  Cassandre     Beaugrand  1997     FRA
# 4     5           5           0      Flora         Duffy  1987     BER
#
#    Total Points  Events First Period  Events Second Period  ...  \
# 0     4135.4400                    6                     0  ...
# 1     4092.8800                    6                     0  ...
# 2     3976.7900                    5                     0  ...
# 3     3666.1245                    6                     0  ...
# 4     3469.8000                    4                     0  ...
#
#    Period 1 5th Score  Period 1 6th Score  Period 1 7th Score  \
# 0              593.59            593.5900                 NaN
# 1              549.07            495.7600                 NaN
# 2              251.79                 NaN                 NaN
# 3              507.89            399.7245                 NaN
# 4                 NaN                 NaN                 NaN
#
#    Period 2 Best Score  Period 2 2nd Score  Period 2 3rd Score  \
# 0                  NaN                 NaN                 NaN
# 1                  NaN                 NaN                 NaN
# 2                  NaN                 NaN                 NaN
# 3                  NaN                 NaN                 NaN
# 4                  NaN                 NaN                 NaN
#
#    Period 2 4th Score  Period 2 5th Score  Period 2 6th Score  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#    Period 2 7th Score
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#
# [5 rows x 26 columns]

# %%
#only keep columns 'col1' and 'col2'
elite_women = elite_women[['Rank', 'First Name', 'Last Name', 'Country', 'Total Points']]

# %%
mixedrelay.head()
# Out:
#    Rank  Prior Rank  Rank Change             Team Name Country  Total Points  \
# 0     1           1            0  Team I Great Britain     GBR       2465.00
# 1     2           2            0         Team I France     FRA       2334.50
# 2     3           3            0        Team I Germany     GER       2085.75
# 3     4           4            0    Team I New Zealand     NZL       1917.13
# 4     5           5            0    Team I Switzerland     SUI       1866.51
#
#    Points Current Period  Points Previous Period  Events Current Period  \
# 0                      0                 2465.00                      0
# 1                      0                 2334.50                      0
# 2                      0                 2085.75                      0
# 3                      0                 1917.13                      0
# 4                      0                 1866.51                      0
#
#    Events Previous Period  Current Best Score  Current 2nd Score  \
# 0                       3                 NaN                NaN
# 1                       3                 NaN                NaN
# 2                       3                 NaN                NaN
# 3                       3                 NaN                NaN
# 4                       3                 NaN                NaN
#
#    Current 3rd Score  Previous Best Score  Previous 2nd Score  \
# 0                NaN               925.00              800.00
# 1                NaN              1000.00              684.50
# 2                NaN               800.00              684.50
# 3                NaN               791.45              585.68
# 4                NaN               677.19              633.16
#
#    Previous 3rd Score
# 0              740.00
# 1              650.00
# 2              601.25
# 3              540.00
# 4              556.16

# %%
#only keep columns 'col1' and 'col2'
mixedrelay = mixedrelay[['Rank', 'Team Name', 'Country', 'Total Points']]

# %%
# Import files from triathlon.com for verification Tableau

world_men = pd.read_csv(r'C:\Users\andyr\OneDrive\Desktop\USOPC\WorldRankingsEliteMen.csv')
world_women = pd.read_csv(r'C:\Users\andyr\OneDrive\Desktop\USOPC\WorldRankingsEliteWomen.csv')
worldmixedrelay = pd.read_csv(r'C:\Users\andyr\OneDrive\Desktop\USOPC\MixedRelayMixedRelay.csv')

#only keep columns 'col1' and 'col2'
world_men = world_men[['Rank', 'First Name', 'Last Name', 'Country', 'Total Points']]
world_men.head()
# Out:
#    Rank First Name Last Name Country  Total Points
# 0     1       Alex       Yee     GBR       6386.37
# 1     2        L�o   Bergere     FRA       6243.86
# 2     3     Hayden     Wilde     NZL       5442.82
# 3     4    Vincent      Luis     FRA       4759.69
# 4     5      Jelle     Geens     BEL       4632.83

# %%
#only keep columns 'col1' and 'col2'
world_women = world_women[['Rank', 'First Name', 'Last Name', 'Country', 'Total Points']]
world_women.head()
# Out:
#    Rank First Name     Last Name Country  Total Points
# 0     1      Flora         Duffy     BER       5545.76
# 1     2    Georgia  Taylor-Brown     GBR       5405.95
# 2     3     Taylor        Spivey     USA       5337.53
# 3     4       Beth        Potter     GBR       4980.99
# 4     5     Taylor         Knibb     USA       4700.70

# %%
#only keep columns 'col1' and 'col2'
worldmixedrelay = worldmixedrelay[['Rank', 'Team Name', 'Country', 'Total Points']]
worldmixedrelay.head()
# Out:
#    Rank             Team Name Country  Total Points
# 0     1  Team I Great Britain     GBR       2930.84
# 1     2        Team I Germany     GER       2763.89
# 2     3         Team I France     FRA       2586.15
# 3     4    Team I New Zealand     NZL       2428.85
# 4     5    Team I Switzerland     SUI       2269.04

# %%
#filter table for US athletes (top 30(qualification) and top 140(world))
# How many US atlhetes are currently on track to qualify?

# selecting rows based on condition 
us_men_rankings = world_men[world_men['Country'] == 'USA'] 
    
print('\nResult dataframe :\n', us_men_rankings)
# Out:
# Result dataframe :
#        Rank First Name       Last Name Country  Total Points
# 11      12    Matthew         Mcelroy     USA       2984.55
# 27      28       Seth           Rider     USA       2230.05
# 47      48     Morgan         Pearson     USA       1802.39
# 51      52      Kevin        Mcdowell     USA       1738.09
# 56      57      Chase         McQueen     USA       1673.21
# 71      72       Darr           Smith     USA       1492.70
# 124    125       John            Reed     USA        958.93
# 143    144       Marc         Dubrick     USA        861.44
# 145    146      Brent        Demarest     USA        858.93
# 168    169     Austin         Hindman     USA        768.72
# 175    176      Ka'eo           Kruse     USA        742.03
# 180    181   Nicholas          Holmes     USA        729.18
# 193    194     Andrew   Shellenberger     USA        671.52
# 197    198      Davis            Bove     USA        639.36
# 200    201    Michael        Arishita     USA        631.03
# 270    271     Thomas  Sonnery-Cottet     USA        429.78
# 272    273      Griff          Morgan     USA        429.10
# 292    293  Nathan F.           Cohen     USA        394.66
# 298    299      Reese       Vannerson     USA        389.11
# 364    365   Sullivan        Middaugh     USA        258.74
# 379    380     Andrew         Trouard     USA        235.28
# 423    424       Ryan            Lund     USA        187.07
# 463    464       Luke         Anthony     USA        153.75
# 487    488       Adoh         Doherty     USA        137.08
# 507    508     Keller         Norland     USA        125.31
# 538    539    Braxton            Legg     USA        108.23
# 544    545       Jake         Baugher     USA        104.10
# 565    566     Carter     Stuhlmacher     USA         96.30
# 596    597       Ryan          Luczak     USA         82.40
# 645    646       Zach        Leachman     USA         70.50
# 648    649    Braxton           Bokos     USA         70.35
# 688    689       Luis           Ortiz     USA         62.55
# 705    706     Daniel          Gossow     USA         56.51
# 741    742       Cole       Jamieson�     USA         49.63
# 751    752    Matthew          Mcgoey     USA         47.74
# 781    781      Jacob        Burgener     USA         44.16
# 806    807    Gregory          Harper     USA         40.85
# 929    930      James         Shalvoy     USA         29.44
# 932    933     Trevor           Foley     USA         29.11
# 938    939        Eli         Hemming     USA         27.74
# 955    956       Tony    Smoragiewicz     USA         25.94
# 965    964       Brad          Murray     USA         23.67
# 984    985        Ben          Kanute     USA         20.14
# 1001  1002       Lane          Hollis     USA         17.33
# 1064  1065      Derek         Oskutis     USA         12.43
# 1110  1111      Cavan          Wilson     USA          7.95
# 1129  1130    Matthew          Murray     USA          5.27
# 1137  1138   Fielding         Fischer     USA          4.51

# %% [markdown]
# ### zero qualified
# ### seven on track
#
# ##        Rank First Name       Last Name Country  Total Points
# ### 11      12    Matthew         Mcelroy     USA       2984.55
# ### 27      28       Seth           Rider     USA       2230.05
# ### 47      48     Morgan         Pearson     USA       1802.39
# ### 51      52      Kevin        Mcdowell     USA       1738.09
# ### 56      57      Chase         McQueen     USA       1673.21
# ### 71      72       Darr           Smith     USA       1492.70
# ### 124    125       John            Reed     USA        958.93

# %%
#filter table for US athletes (top 30(qualification) and top 140(world))
# How many US atlhetes are currently on track to qualify?

# selecting rows based on condition 
us_men_elite_rankings = elite_men[elite_men['Country'] == 'USA'] 
    
print('\nResult dataframe :\n', us_men_elite_rankings)
# Out:
# Result dataframe :
#       Rank First Name       Last Name Country  Total Points
# 8       9    Matthew         McElroy     USA       2648.18
# 31     32       Seth           Rider     USA       1467.44
# 41     42     Morgan         Pearson     USA       1164.47
# 68     69      Kevin        Mcdowell     USA        741.14
# 69     70       Darr           Smith     USA        718.74
# 71     72      Chase         McQueen     USA        697.53
# 134   135      Brent        Demarest     USA        228.59
# 168   169    Michael        Arishita     USA        131.87
# 188   189     Austin         Hindman     USA         69.28
# 205   206     Thomas  Sonnery-Cottet     USA         48.87
# 206   207      Davis            Bove     USA         45.49
# 213   214      Griff          Morgan     USA         30.56
# 223   224     Andrew   Shellenberger     USA         20.95
# 235   236       Ryan            Lund     USA         12.14
# 241   241       Marc         Dubrick     USA          8.22

# %% [markdown]
# ### zero qualified
# ### one on track
#
# ##      Rank First Name       Last Name Country  Total Points
# ### 8       9    Matthew         McElroy     USA       2648.18

# %%
#filter table for US athletes (top 30(qualification) and top 140(world))
# How many US atlhetes are currently on track to qualify?

# selecting rows based on condition 
us_women_rankings = world_women[world_women['Country'] == 'USA'] 
    
print('\nResult dataframe :\n', us_women_rankings)
# Out:
# Result dataframe :
#       Rank First Name   Last Name Country  Total Points
# 2       3     Taylor      Spivey     USA       5337.53
# 4       5     Taylor       Knibb     USA       4700.70
# 14     15    Kirsten      Kasper     USA       3084.80
# 15     16     Summer   Rappaport     USA       3054.02
# 28     29      Erika   Ackerlund     USA       2317.10
# 44     45       Gina      Sereno     USA       1772.11
# 94     95      Katie     Zaferes     USA       1196.56
# 148   149  Gabrielle      Lumkes     USA        808.16
# 176   177      Lydia     Russell     USA        669.61
# 209   210    Madisen       Lavin     USA        532.20
# 220   221       Gwen   Jorgensen     USA        498.80
# 222   223      Grace     Walther     USA        489.29
# 224   225     Tamara      Gorman     USA        479.95
# 255   256      Annie       Kelly     USA        362.63
# 260   261      Faith       Dasso     USA        351.04
# 267   268      Annie      Fuller     USA        337.67
# 277   278   Michelle    Stratton     USA        310.72
# 283   284    Liberty       Ricca     USA        302.95
# 340   341    Britney       Brown     USA        198.78
# 362   363      Renee      Tomlin     USA        156.92
# 381   382    Kyleigh    Spearing     USA        147.21
# 388   389  Alexandra       Poole     USA        142.64
# 422   423      Freya    Mckinley     USA        110.03
# 429   430      Megan       Foley     USA        105.64
# 439   440    Gillian      Cridge     USA         98.13
# 464   465        Amy       Sloan     USA         83.61
# 515   516      Naomi        Ruff     USA         63.67
# 532   533       Erin  Edminister     USA         59.10
# 549   550      Jenna    Buchanan     USA         53.65
# 573   574      Gabby      Martin     USA         49.04
# 650   651      Batya       Beard     USA         32.33
# 701   702    Camille    Buchanan     USA         21.74
# 737   738      Molly     Elliott     USA         14.39
# 789   790     Hannah     Sakaluk     USA          9.84
# 796   797       Kira     Stanley     USA          8.42

# %% [markdown]
# ### zero qualified
# ### seven on track
#
# ##       Rank First Name   Last Name Country  Total Points
# ### 2       3     Taylor      Spivey     USA       5337.53
# ### 4       5     Taylor       Knibb     USA       4700.70
# ### 14     15    Kirsten      Kasper     USA       3084.80
# ### 15     16     Summer   Rappaport     USA       3054.02
# ### 28     29      Erika   Ackerlund     USA       2317.10
# ### 44     45       Gina      Sereno     USA       1772.11
# ### 94     95      Katie     Zaferes     USA       1196.56

# %%
#filter table for US athletes (top 30(qualification) and top 140(world))
# How many US atlhetes are currently on track to qualify?

# selecting rows based on condition 
us_women_elite_rankings = elite_women[elite_women['Country'] == 'USA'] 
    
print('\nResult dataframe :\n', us_women_elite_rankings)
# Out:
# Result dataframe :
#       Rank First Name  Last Name Country  Total Points
# 0       1     Taylor     Spivey     USA       4135.44
# 9      10     Taylor      Knibb     USA       2769.95
# 14     15     Summer  Rappaport     USA       2222.20
# 23     24    Kirsten     Kasper     USA       1791.88
# 30     31      Erika  Ackerlund     USA       1562.41
# 63     64       Gina     Sereno     USA        831.86
# 107   108     Tamara     Gorman     USA        303.91
# 142   143       Gwen  Jorgensen     USA        136.10
# 177   178      Katie    Zaferes     USA         45.31
# 178   179      Annie      Kelly     USA         42.47
# 183   184    Madisen      Lavin     USA         33.45

# %% [markdown]
# ### zero qualified
# ### four on track
#
# ##      Rank First Name  Last Name Country  Total Points
# ### 0       1     Taylor     Spivey     USA       4135.44
# ### 9      10     Taylor      Knibb     USA       2769.95
# ### 14     15     Summer  Rappaport     USA       2222.20
# ### 23     24    Kirsten     Kasper     USA       1791.88

# %%
# Export tables as csv

us_men_rankings.to_csv(r'C:\Users\andyr\OneDrive\Desktop\USOPC\us_men_rankings.csv')
us_women_rankings.to_csv(r'C:\Users\andyr\OneDrive\Desktop\USOPC\us_women_rankings.csv')
us_men_elite_rankings.to_csv(r'C:\Users\andyr\OneDrive\Desktop\USOPC\us_men_elite_rankings.csv')
us_women_elite_rankings.to_csv(r'C:\Users\andyr\OneDrive\Desktop\USOPC\us_women_elite_rankings.csv')
